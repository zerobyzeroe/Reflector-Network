# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models, regularizers
import matplotlib.pyplot as plt

# %%
def build_autoencoder_with_l2(input_shape):
    l2_reg = regularizers.l2(0.001) 
    # Encoder
    encoder_input = layers.Input(shape=input_shape)
    x = layers.Dense(32, activation='relu', kernel_regularizer=l2_reg)(encoder_input)
    latent_space = layers.Dense(16, activation='relu', kernel_regularizer=l2_reg)(x)
    # Decoder
    x = layers.Dense(32, activation='relu', kernel_regularizer=l2_reg)(latent_space)
    decoder_output = layers.Dense(input_shape[0], activation='linear', kernel_regularizer=l2_reg)(x)
    # Autoencoder model
    autoencoder = models.Model(encoder_input, decoder_output)
    return autoencoder

# %%
def generate_data(samples=1000, features=20):
    X = np.random.randn(samples, features)
    return X, X

# %%
class WeightTracker(tf.keras.callbacks.Callback):
    def __init__(self):
        super().__init__()
        self.weights_history = []
    def on_epoch_end(self, epoch, logs=None):
        self.weights_history.append(self.model.layers[1].get_weights()[0].flatten())

# %%
# Generate random data
X_train, y_train = generate_data()
input_shape = (X_train.shape[1],)
autoencoder = build_autoencoder_with_l2(input_shape)

autoencoder.compile(optimizer='adam', loss='mse')

weight_tracker = WeightTracker()
history = autoencoder.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2, verbose=1, callbacks=[weight_tracker])
# Out:
# Epoch 1/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 1.1649 - val_loss: 1.0914
# Epoch 2/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 1.0875 - val_loss: 1.0518
# Epoch 3/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 976us/step - loss: 1.0327 - val_loss: 1.0144
# Epoch 4/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 1.0162 - val_loss: 0.9710
# Epoch 5/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 883us/step - loss: 0.9596 - val_loss: 0.9210
# Epoch 6/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 878us/step - loss: 0.8822 - val_loss: 0.8613
# Epoch 7/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.8399 - val_loss: 0.7980
# Epoch 8/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 897us/step - loss: 0.7747 - val_loss: 0.7466
# Epoch 9/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 996us/step - loss: 0.7339 - val_loss: 0.7071
# Epoch 10/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6625 - val_loss: 0.6736
# Epoch 11/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6360 - val_loss: 0.6392
# Epoch 12/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 964us/step - loss: 0.5907 - val_loss: 0.6132
# Epoch 13/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.5727 - val_loss: 0.5810
# Epoch 14/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 0.5362 - val_loss: 0.5525
# Epoch 15/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 909us/step - loss: 0.5179 - val_loss: 0.5306
# Epoch 16/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.4844 - val_loss: 0.5114
# Epoch 17/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 0.4710 - val_loss: 0.4922
# Epoch 18/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 0.4476 - val_loss: 0.4821
# Epoch 19/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 895us/step - loss: 0.4299 - val_loss: 0.4644
# Epoch 20/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.4160 - val_loss: 0.4532
# Epoch 21/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.4050 - val_loss: 0.4408
# Epoch 22/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 925us/step - loss: 0.3923 - val_loss: 0.4295
# Epoch 23/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.3786 - val_loss: 0.4264
# Epoch 24/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - loss: 0.3848 - val_loss: 0.4216
# Epoch 25/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 903us/step - loss: 0.3684 - val_loss: 0.4176
# Epoch 26/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3545 - val_loss: 0.4204
# Epoch 27/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 871us/step - loss: 0.3557 - val_loss: 0.4120
# Epoch 28/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - loss: 0.3577 - val_loss: 0.4039
# Epoch 29/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 913us/step - loss: 0.3567 - val_loss: 0.4007
# Epoch 30/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.3431 - val_loss: 0.3981
# Epoch 31/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.3422 - val_loss: 0.3943
# Epoch 32/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 893us/step - loss: 0.3460 - val_loss: 0.3923
# Epoch 33/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 982us/step - loss: 0.3385 - val_loss: 0.3893
# Epoch 34/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 963us/step - loss: 0.3286 - val_loss: 0.3893
# Epoch 35/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 971us/step - loss: 0.3356 - val_loss: 0.3827
# Epoch 36/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 956us/step - loss: 0.3256 - val_loss: 0.3858
# Epoch 37/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 0.3294 - val_loss: 0.3764
# Epoch 38/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 0.3207 - val_loss: 0.3728
# Epoch 39/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 901us/step - loss: 0.3146 - val_loss: 0.3698
# Epoch 40/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 904us/step - loss: 0.3199 - val_loss: 0.3651
# Epoch 41/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3130 - val_loss: 0.3635
# Epoch 42/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.3186 - val_loss: 0.3609
# Epoch 43/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 962us/step - loss: 0.3062 - val_loss: 0.3575
# Epoch 44/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.3065 - val_loss: 0.3552
# Epoch 45/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2975 - val_loss: 0.3553
# Epoch 46/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.2947 - val_loss: 0.3515
# Epoch 47/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 890us/step - loss: 0.2978 - val_loss: 0.3487
# Epoch 48/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 899us/step - loss: 0.2883 - val_loss: 0.3457
# Epoch 49/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 902us/step - loss: 0.2936 - val_loss: 0.3456
# Epoch 50/50
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - loss: 0.2934 - val_loss: 0.3408

# %%
# Plot the training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss with L2 Regularization')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
predictions = autoencoder.predict(X_train)

plt.figure(figsize=(12, 6))
num_samples = 10 
for i in range(num_samples):
    plt.plot(predictions[i], label=f'Sample {i+1}')

plt.title('Autoencoder Predictions with L2 Regularization')
plt.xlabel('Feature Index')
plt.ylabel('Prediction Value')
plt.axhline(y=0, color='r', linestyle='--', label='Zero Reference')
plt.legend(loc='upper right')
plt.show()
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
weights_history = np.array(weight_tracker.weights_history)

# Plot the weight fluctuations over epochs
plt.figure(figsize=(12, 6))
for i in range(min(10, weights_history.shape[1])):  # Plot a few weight fluctuations
    plt.plot(weights_history[:, i], label=f'Weight {i+1}')

plt.title('Weight Fluctuations Across Epochs')
plt.xlabel('Epoch')
plt.ylabel('Weight Value')
plt.legend(loc='upper right')
plt.show()
